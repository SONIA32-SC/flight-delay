# %%
#Importing libraries

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# loading dataset

fl_process = pd.read_csv('fl_eda.csv')
# Out:
# C:\Users\sonia\AppData\Local\Temp\ipykernel_37144\1420190565.py:3: DtypeWarning: Columns (17,18,31,33,35,36,37,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   fl_process = pd.read_csv('fl_eda.csv')

# %%
fl_process.head()
# Out:
#    Unnamed: 0  YEAR  MONTH  DAY  DAY_OF_WEEK  DEPARTURE_TIME  \
# 0           0  2008      1    3            4            2003
# 1           1  2008      1    3            4             754
# 2           2  2008      1    3            4             628
# 3           3  2008      1    3            4            1829
# 4           4  2008      1    3            4            1940
#
#    SCHEDULED_DEPARTURE  ARRIVAL_TIME  SCHEDULED_ARRIVAL  \
# 0                 1955        2211.0               2225
# 1                  735        1002.0               1000
# 2                  620         804.0                750
# 3                 1755        1959.0               1925
# 4                 1915        2121.0               2110
#
#                   AIRLINE  ...     id ident            type  \
# 0  Southwest Airlines Co.  ...   3356  KABE  medium_airport
# 1  Southwest Airlines Co.  ...   3357  KABI  medium_airport
# 2  Southwest Airlines Co.  ...  16091  KABQ   large_airport
# ...

# %%
# Removing unnecessary columns

fl_process = fl_process.drop(columns=['Unnamed: 0','AIRLINE_DELAY','DEPARTURE_DELAY','NAS_DELAY','DESTINATION_AIRPORT','ORIGIN_AIRPORT','LATE_AIRCRAFT_DELAY','iso_region','SECURITY_DELAY','id','ident','AIR_SYSTEM_DELAY','ARRIVAL_DELAY', 'WEATHER_DELAY','CANCELLATION_REASON', 'type','name','TAIL_NUMBER','latitude_deg','longitude_deg','elevation_ft','iso_country','iata_code'],axis= 1)

# %%
fl_process.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK  DEPARTURE_TIME  SCHEDULED_DEPARTURE  \
# 0  2008      1    3            4            2003                 1955
# 1  2008      1    3            4             754                  735
# 2  2008      1    3            4             628                  620
# 3  2008      1    3            4            1829                 1755
# 4  2008      1    3            4            1940                 1915
#
#    ARRIVAL_TIME  SCHEDULED_ARRIVAL                 AIRLINE  FLIGHT_NUMBER  \
# 0        2211.0               2225  Southwest Airlines Co.            335
# 1        1002.0               1000  Southwest Airlines Co.           3231
# 2         804.0                750  Southwest Airlines Co.            448
# 3        1959.0               1925  Southwest Airlines Co.           3920
# 4        2121.0               2110  Southwest Airlines Co.            378
#
#    ...  SCHEDULED_TIME  AIR_TIME  DISTANCE  TAXI_IN  TAXI_OUT  CANCELLED  \
# ...

# %%
# Encoding categorical variables

fl_process = pd.get_dummies(fl_process, columns=['AIRLINE','IATA_CODE'])
fl_process
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK  DEPARTURE_TIME  SCHEDULED_DEPARTURE  \
# 0        2008      1    3            4            2003                 1955
# 1        2008      1    3            4             754                  735
# 2        2008      1    3            4             628                  620
# 3        2008      1    3            4            1829                 1755
# 4        2008      1    3            4            1940                 1915
# ...       ...    ...  ...          ...             ...                  ...
# 7755832  2015     12   31            4            2355                 2359
# 7755833  2015     12   31            4            2355                 2359
# 7755834  2015     12   31            4            2350                 2359
# 7755835  2015     12   31            4            2353                 2359
# 7755836  2015     12   31            4              14                 2359
#
# ...

# %%
# Choosing to store data types in smaller bits

fl_process[fl_process.select_dtypes(np.float64).columns] = fl_process.select_dtypes(np.float64).astype(np.float16)

# %%
fl_process[fl_process.select_dtypes(np.int64).columns] = fl_process.select_dtypes(np.int64).astype(np.int16)

# %%
# Defining X and y

X= fl_process.drop(columns=['CANCELLED', 'AIRLINES', 'IATA_CODE'])
y= fl_process['CANCELLED']

# %%
# Splitting data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(fl_process, fl_process['CANCELLED'], test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (6204669, 365)

# %%
X_test.shape
# Out:
# (1551168, 365)

# %%
# Saving train and test sets

dataset_dict = {
    "X_train": X_train,
    "X_test": X_test,
    "y_train": y_train,
    "y_test": y_test
}

with open('dataset_dict.pickle', 'wb') as file:
    pickle.dump(dataset_dict, file)

# %% [markdown]
#  **SUMMARY**
#
# At the preprocessing stage of the project, categorical variables like Airline and origin airport were encoded.
#
# X and y variables were defined and data was split into training and test sets in the ratio80:20.
#
#
# Training and t setsmer w eresaved using the pickle mod.ule
